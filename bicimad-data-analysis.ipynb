# %% [markdown]
# # Analyzing BiciMad data
#
# Copyright © 2017 Javi Ramírez <javi.rmrz@gmail.com> | [@rameerez [tw]](http://twitter.com/rameerez) | [GitHub](http://github.com/rameerez)
#
# This software is Open Source, released under the MIT License.
#
# _Made with ♥ from Madrid. April, 2017_
#
# ![EMT Madrid BiciMAD](http://www.imageno.com/image.php?id=h4apsa8ns29m&kk=3486313256)
#
#
# BiciMad is the public bike system in Madrid, Spain. I'm a big fan of commuting by bike in Madrid (even though car drivers are still complete assholes to bike drivers, and the city is not fully conditioned to bike traffic).
#
# I tend to use my own bike, but still I find myself more than often riding BiciMad bikes (it's pretty convenient: they have an electric motor that assists in pedaling, and you can just take and drop them in the nearest station without having to worry about getting your own bike stolen). Still, every time I've used them, I've detected a number of issues (broken bikes, out-of-order plugs, empty and completely full stations...)
#
# In April 2017 I contacted EMT Madrid (the public company that now runs BiciMad) and asked their OpenData department for BiciMad data to analyze. They inmediatly answered and provided me with a huge dataset and helpful documentation. I want to thank EMT's OpenData for their kindness and contribution.
#
# My goal with this data analysis is to discover hidden patterns that can reveal underlying problems, to provide BiciMad with powerful data-based suggestions that can help improve the service for all us Madrid citizens.

# %% [markdown]
# ## Dataset description
#
# Please refer to [EMT BiciMad OpenData docs](http://opendata.emtmadrid.es/Servicios-web/BICIMAD) for updated info. This table is only intended for illustration purposes.
#
# | Field name             | Description                                                                                |
# |------------------------|--------------------------------------------------------------------------------------------|
# | ```_id```              | Travel id                                                                                  |
# | ```user_day_code```    | User id. For a single day, all travels made by the same user will have the same user id.   |
# | ```idunplug_station``` | **Unplug**: station id.                                                                    |
# | ```idunplug_base```    | **Unplug**: base id (base within the station).                                             |
# | ```idplug_station```   | **Plug**: station id.                                                                      |
# | ```idplug_base```      | **Plug**: base id (base within the station).                                               |
# | ```unplug_hourTime```  | Hour at which the travel started, discarding info about minutes and seconds for anonymity. |
# | ```travel_time```      | Time in _seconds_ between bike unplug and bike plug back in.                               |
# | ```track```            | Travel details in GeoJSON format.                                                          |
# | ```user_type```        | 0: undetermined; 1: annual pass; 2: occasional user; 3: BiciMad employee                   |
# | ```ageRange```         | 0: undetermined; 1: [0..16]; 2: [17..18]; 3: [19..26]; 4: [27..40]; 5: [41..65] 6: [>66]   |
# | ```zip_code```         | User's postal code.                                                                        |

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Imports & data loading

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %%
# Watch out! lines=True needed
df = pd.read_json('/Users/javi/Downloads/Bicimad_20170301_20170406/export_20170301_20170406.json', lines=True)
df
# Out:
#                                          _id  ageRange  idplug_base  \
# 0       {'$oid': '58d1b3dd865e9c30d0b83c6f'}         4            4
# 1       {'$oid': '58d1b3dc865e9c30d0b83c6c'}         4            2
# 2       {'$oid': '58d1b3dc865e9c30d0b83c6a'}         5           16
# 3       {'$oid': '58d1b3dd865e9c30d0b83c6e'}         4            2
# 4       {'$oid': '58d1b3dc865e9c30d0b83c69'}         3           16
# 5       {'$oid': '58d1b3dc865e9c30d0b83c6b'}         4           14
# 6       {'$oid': '58d1b3dd865e9c30d0b83c6d'}         4           12
# 7       {'$oid': '58d1b3dc865e9c30d0b83c68'}         4           19
# 8       {'$oid': '58d1b3db865e9c30d0b83c67'}         5            5
# 9       {'$oid': '58d1b3db865e9c30d0b83c65'}         4           13
# 10      {'$oid': '58d1b3db865e9c30d0b83c66'}         4            5
# 11      {'$oid': '58d1b3db865e9c30d0b83c64'}         3           24
# 12      {'$oid': '58d1b3da865e9c30d0b83c63'}         4            2
# 13      {'$oid': '58d1b3da865e9c30d0b83c62'}         5            1
# 14      {'$oid': '58d1b3da865e9c30d0b83c61'}         4           24
# 15      {'$oid': '58d1b3da865e9c30d0b83c60'}         4            9
# 16      {'$oid': '58d1b3da865e9c30d0b83c5f'}         4           11
# 17      {'$oid': '58d1b3da865e9c30d0b83c5e'}         4           13
# 18      {'$oid': '58d1b3d9865e9c30d0b83c5d'}         4           15
# 19      {'$oid': '58d1b3d9865e9c30d0b83c5c'}         3            5
# 20      {'$oid': '58d1b3d9865e9c30d0b83c5b'}         3            5
# 21      {'$oid': '58d1b3d9865e9c30d0b83c5a'}         4            5
# 22      {'$oid': '58d1b3d9865e9c30d0b83c59'}         4            3
# 23      {'$oid': '58d1b3d9865e9c30d0b83c58'}         4           17
# 24      {'$oid': '58d1b3d9865e9c30d0b83c57'}         3            1
# 25      {'$oid': '58d1b3d9865e9c30d0b83c56'}         4           18
# 26      {'$oid': '58d1b3d9865e9c30d0b83c55'}         3           18
# 27      {'$oid': '58d1b3d8865e9c30d0b83c54'}         4            6
# 28      {'$oid': '58d1b3d8865e9c30d0b83c53'}         4           21
# 29      {'$oid': '58d1b3d8865e9c30d0b83c51'}         4           20
# ...                                      ...       ...          ...
# 289951  {'$oid': '58e5e616865e9c221ca47974'}         4           23
# 289952  {'$oid': '58e5e616865e9c221ca47975'}         3            3
# 289953  {'$oid': '58e5e616865e9c221ca47976'}         3            5
# 289954  {'$oid': '58e5e616865e9c221ca47977'}         3           22
# 289955  {'$oid': '58e5e616865e9c221ca47978'}         1            1
# 289956  {'$oid': '58e5e616865e9c221ca47979'}         5           19
# 289957  {'$oid': '58e5e616865e9c221ca4797a'}         3            1
# 289958  {'$oid': '58e5e616865e9c221ca4797b'}         0           16
# 289959  {'$oid': '58e5e616865e9c221ca4797c'}         5            4
# 289960  {'$oid': '58e5e616865e9c221ca4797d'}         2            4
# 289961  {'$oid': '58e5e616865e9c221ca4797f'}         5            6
# 289962  {'$oid': '58e5e616865e9c221ca47980'}         4            4
# 289963  {'$oid': '58e5e616865e9c221ca47981'}         4            4
# 289964  {'$oid': '58e5e616865e9c221ca47982'}         5           22
# 289965  {'$oid': '58e5e616865e9c221ca47983'}         4            7
# 289966  {'$oid': '58e5e616865e9c221ca47984'}         5           24
# 289967  {'$oid': '58e5e616865e9c221ca47985'}         5            2
# 289968  {'$oid': '58e5e616865e9c221ca47986'}         5           22
# 289969  {'$oid': '58e5e616865e9c221ca47987'}         4           13
# 289970  {'$oid': '58e5e616865e9c221ca47988'}         3            6
# 289971  {'$oid': '58e5e616865e9c221ca47989'}         4            1
# 289972  {'$oid': '58e5e616865e9c221ca4798a'}         4            4
# 289973  {'$oid': '58e5e616865e9c221ca4798b'}         3            1
# 289974  {'$oid': '58e5e616865e9c221ca4798c'}         4           24
# 289975  {'$oid': '58e5e616865e9c221ca4798d'}         4           22
# 289976  {'$oid': '58e5e616865e9c221ca4798e'}         3            8
# 289977  {'$oid': '58e5e616865e9c221ca4798f'}         3           21
# 289978  {'$oid': '58e5e616865e9c221ca47990'}         4            8
# 289979  {'$oid': '58e5e616865e9c221ca47992'}         3            2
# 289980  {'$oid': '58e5e616865e9c221ca47993'}         4            2
#
#         idplug_station  idunplug_base  idunplug_station  \
# 0                   17              5                14
# 1                   76             22               123
# 2                  163             19               166
# 3                   69             18               113
# 4                   63              1                10
# 5                   17              5                 4
# 6                   71              3               142
# 7                   80              3                74
# 8                   22             21                30
# 9                  129             17                55
# 10                  38              6                26
# 11                 118              2               146
# 12                  17              2               130
# 13                 168              1               168
# 14                  57              1                59
# 15                  23              9                23
# 16                  25              9                14
# 17                  25             11                14
# 18                  25             12                14
# 19                  30              6               149
# 20                 128              5                45
# 21                  25             16                14
# 22                  25             17                14
# 23                  25             13                14
# 24                  48             24                62
# 25                 128              3                46
# 26                 129              9                21
# 27                 157             22               107
# 28                  10              9                52
# 29                 174             24                44
# ...                ...            ...               ...
# 289951             129              4                46
# 289952              43              2                57
# 289953              71              1                27
# 289954              55              1                43
# 289955              27             17                38
# 289956              47             24                 2
# 289957              38              2               125
# 289958             172              6               146
# 289959             166              5                96
# 289960              42              8                42
# 289961              82              5                86
# 289962             156              4               142
# 289963             174             24                57
# 289964              79              6                45
# 289965             174             15                57
# 289966              79              2                45
# 289967              23              4                 5
# 289968             132              9               129
# 289969             157             13               157
# 289970             116             24                84
# 289971              43             23                47
# 289972             142             19                12
# 289973              16             21               117
# 289974             135              6                59
# 289975              38             23                38
# 289976              45             21                26
# 289977              35             13               121
# 289978              12              5                43
# 289979             133             20                54
# 289980              32             21                90
#
#                                                     track  travel_time  \
# 0                                                     NaN         2303
# 1                                                     NaN          876
# 2                                                     NaN          483
# 3                                                     NaN          105
# 4                                                     NaN          327
# 5                                                     NaN          480
# 6                                                     NaN         1034
# 7                                                     NaN          263
# 8                                                     NaN          150
# 9                                                     NaN          138
# 10                                                    NaN          237
# 11                                                    NaN          576
# 12                                                    NaN          407
# 13                                                    NaN          928
# 14                                                    NaN          545
# 15                                                    NaN           18
# 16                                                    NaN         1822
# 17                                                    NaN         1906
# 18                                                    NaN         1914
# 19                                                    NaN          860
# 20                                                    NaN          278
# 21                                                    NaN         2168
# 22                                                    NaN         2208
# 23                                                    NaN         2097
# 24                                                    NaN         1319
# 25                                                    NaN          368
# 26                                                    NaN          429
# 27                                                    NaN          606
# 28                                                    NaN          371
# 29                                                    NaN         1464
# ...                                                   ...          ...
# 289951  {'FeatureCollection': {'Features': [{'properti...          308
# 289952  {'FeatureCollection': {'Features': [{'properti...          338
# 289953  {'FeatureCollection': {'Features': [{'properti...          439
# 289954                                                NaN          318
# 289955                                                NaN          224
# 289956                                                NaN          330
# 289957  {'FeatureCollection': {'Features': [{'properti...          791
# 289958  {'FeatureCollection': {'Features': [{'properti...          310
# 289959  {'FeatureCollection': {'Features': [{'properti...          410
# 289960                                                NaN           27
# 289961                                                NaN          450
# 289962  {'FeatureCollection': {'Features': [{'properti...          402
# 289963  {'FeatureCollection': {'Features': [{'properti...         1571
# 289964  {'FeatureCollection': {'Features': [{'properti...          927
# 289965  {'FeatureCollection': {'Features': [{'properti...         1539
# 289966  {'FeatureCollection': {'Features': [{'properti...          923
# 289967  {'FeatureCollection': {'Features': [{'properti...          313
# 289968                                                NaN         1104
# 289969                                                NaN           14
# 289970                                                NaN         1048
# 289971  {'FeatureCollection': {'Features': [{'properti...          270
# 289972                                                NaN         1266
# 289973  {'FeatureCollection': {'Features': [{'properti...          385
# 289974  {'FeatureCollection': {'Features': [{'properti...         1263
# 289975                                                NaN           13
# 289976  {'FeatureCollection': {'Features': [{'properti...          432
# 289977                                                NaN          347
# 289978                                                NaN          648
# 289979                                                NaN          339
# 289980  {'FeatureCollection': {'Features': [{'properti...          375
#
#                                   unplug_hourTime  \
# 0       {'$date': '2017-03-01T00:00:00.000+0100'}
# 1       {'$date': '2017-03-01T00:00:00.000+0100'}
# 2       {'$date': '2017-03-01T00:00:00.000+0100'}
# 3       {'$date': '2017-03-01T00:00:00.000+0100'}
# 4       {'$date': '2017-03-01T00:00:00.000+0100'}
# 5       {'$date': '2017-03-01T00:00:00.000+0100'}
# 6       {'$date': '2017-03-01T00:00:00.000+0100'}
# 7       {'$date': '2017-03-01T00:00:00.000+0100'}
# 8       {'$date': '2017-03-01T00:00:00.000+0100'}
# 9       {'$date': '2017-03-01T00:00:00.000+0100'}
# 10      {'$date': '2017-03-01T00:00:00.000+0100'}
# 11      {'$date': '2017-03-01T00:00:00.000+0100'}
# 12      {'$date': '2017-03-01T00:00:00.000+0100'}
# 13      {'$date': '2017-03-01T00:00:00.000+0100'}
# 14      {'$date': '2017-03-01T00:00:00.000+0100'}
# 15      {'$date': '2017-03-01T00:00:00.000+0100'}
# 16      {'$date': '2017-03-01T00:00:00.000+0100'}
# 17      {'$date': '2017-03-01T00:00:00.000+0100'}
# 18      {'$date': '2017-03-01T00:00:00.000+0100'}
# 19      {'$date': '2017-03-01T00:00:00.000+0100'}
# 20      {'$date': '2017-03-01T00:00:00.000+0100'}
# 21      {'$date': '2017-03-01T00:00:00.000+0100'}
# 22      {'$date': '2017-03-01T00:00:00.000+0100'}
# 23      {'$date': '2017-03-01T00:00:00.000+0100'}
# 24      {'$date': '2017-03-01T00:00:00.000+0100'}
# 25      {'$date': '2017-03-01T00:00:00.000+0100'}
# 26      {'$date': '2017-03-01T00:00:00.000+0100'}
# 27      {'$date': '2017-03-01T00:00:00.000+0100'}
# 28      {'$date': '2017-03-01T00:00:00.000+0100'}
# 29      {'$date': '2017-03-01T00:00:00.000+0100'}
# ...                                           ...
# 289951  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289952  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289953  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289954  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289955  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289956  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289957  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289958  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289959  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289960  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289961  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289962  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289963  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289964  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289965  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289966  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289967  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289968  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289969  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289970  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289971  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289972  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289973  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289974  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289975  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289976  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289977  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289978  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289979  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289980  {'$date': '2017-04-01T22:00:00.000+0100'}
#
#                                             user_day_code  user_type zip_code
# 0       cc6d426ada96494d8dfe0fe0af512599f439cd9413d50c...          1    28012
# 1       a81b44c3fe3c2f1e4bf723d228a0d025962228179c2e4d...          1    28009
# 2       b20f0b657c493842b0aa5ebd32eed5d940c699715ee8bc...          1    28010
# 3       4da645df4816870214c627aa9b5e6da41098473a9ee111...          1    28045
# 4       521c11677963dcb892b589f0a6f08d1e6060624d410c61...          1    28004
# 5       425f3fb3c2433f795a50ad702629c6212bd304d543b61f...          3
# 6       bb42e757240175c0e80da446903a51412403d82d4ce397...          1    28020
# 7       03acc26b8494413f2fcfd2087ed616efd16bcdc532c2c9...          1    28023
# 8       30db9b39331a505f1b5aaec6ba013fa671081c6c2ac1be...          1    28400
# 9       1297e961c792b87667436e29fd7cb95784085675512a9d...          1    28045
# 10      ff234fef9b4bbe080a1d1147f3d238fb74ae0f2e784e2e...          1    28019
# 11      1f880462bb8d04cfa4878c0c09afafdde82c18a1ee5d8d...          1    28016
# 12      f76f58bb66af5cb0641c46d999c4df4cbe793ba9c07efe...          1    28010
# 13      d7e4ae31611e9b5997cc7db165e84f3cbe9d280f8df9a6...          1    28015
# 14      0c050f1d9f902714085dfb5ad724102067937547ae78b6...          1    28012
# 15      4a65b9e0af4c4b1886e9c8228b8b7304930b2c7d859634...          1    28006
# 16      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 17      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 18      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 19      05c71f1b96d146c4f3e8353b9a685cf60e5443139b7f9e...          1    28004
# 20      00699f4d60671361e1bd643297eaf3061c9353258d34c4...          1    28045
# 21      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 22      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 23      36dd21eba16bc6cc5d42d5e5611ed8aff5c21965db2f13...          3
# 24      9fb1071ae041defa24754b3124fe51b7dcbd09d74bf054...          1    28012
# 25      df2b222c94a2c3b8f9a04d44697e654bc7a17176bfcf76...          1    28021
# 26      253c5385091150e771f56bd3b30d8425c99a50c5757653...          1    28045
# 27      62dbdc5edafd0d41075de1e73e6f11d94b9a40917f8687...          1    28003
# 28      6faded09110f8fd9730b117c2b72bc1bc620a1a446c2d0...          1    28013
# 29      7bbabc2bd8c5f745338242f3c24b7609d5c086dfe13e30...          1    28012
# ...                                                   ...        ...      ...
# 289951  7bdc628e79807786937776956301d3b099bed8e190ddae...          1    28012
# 289952  f74f3466116304667b42e8df94842ad9b0e6c9a2683cbb...          1    28012
# 289953  e55feef66ca09bf8335227d303eb20ba516179dcbd3098...          1    28013
# 289954  81eb3ce54c49202e31ad30644c2255196f34329d97dc2e...          1    28005
# 289955  87ffe87333cf742c7def396941a202c54bc0a9db4f2d44...          1    28013
# 289956  3d54e0f8c0db8b23602116019c2a8fa48f239fcfd7fd1b...          1
# 289957  55a1dde0d51ef0098b990f45a8331b559b58f7a197d4b8...          1    28008
# 289958  ec3bf64db8dcc61331a4f0b360d2fb942cfe0ee56a80bd...          0
# 289959  feb4e523dd8bdaed99a086e02c799b14d10dac34f4d957...          1    28006
# 289960  cf387c3a80d5597d86028dd580c6e07e429853a5a16dcb...          1    28005
# 289961  b1a54eff94afe0cdceac8c93fcbe6e569b2871267a9959...          1    28006
# 289962  7471b559470ac9c115db40a361e3c4e28d8dcfe0023ecf...          1    28020
# 289963  fc89c0a887e5dc9424259e68e737cdb67fde60c0158aef...          1    28012
# 289964  3b1f9f91e0194213409a23f4a58a065871e539e8505514...          1    28007
# 289965  5e6d144ba80275898265ed580b742111b6e6b06c65e9aa...          1    28012
# 289966  97aa3a0552ed415e3fe56398a1aeed0c6004fc2c33d5ab...          1    28007
# 289967  7f9d5f10a1bdc65187778658a562310624a1d35717677d...          1    28010
# 289968  b3d36afc181b43eeabf994732cfe12c6fbd44a2a365c00...          1    28045
# 289969  b51374da5dc255e9b6018bc53e714ff112a04ff766b8e5...          3
# 289970  6fdca58f50be7331b7e4afc8f4437c91f9194576286051...          1    28011
# 289971  4e4353dbc7cd56a8b4760e61df8b23ba93a2f68f8132c5...          1    28005
# 289972  6b8ae3e7f6a80fa854b9a9fa2a698793e67a7736bef874...          1    28039
# 289973  3ef2414f61641985c65b3a447f35e6017741ae698f5fb2...          1    28006
# 289974  ad10cf2263701c272a1191fb5fb81fbc3490d017ffee05...          1    28045
# 289975  33d0ad733972d9d5b85a6906af8071c2192d08738e23aa...          1    28012
# 289976  ed0eee7b71b57bae149c9dce6ea368d06e3cd666050a85...          1    28024
# 289977  4fdccd1aee96eaec2f920166e53ea75ca91ba2bf0260a2...          1    28008
# 289978  aa482c72c935510d770c3565e55d04c2da5bba48db2e2b...          1    28003
# 289979  83623957ccfa4ae45fd8c804c94b1b3e6b0b0211055ce3...          1    28028
# 289980  0580d62266cb3c4753b665211f467574747ab36c33e94a...          1    28009
#
# [289981 rows x 12 columns]

# %% [markdown]
# ## 2. Exploratory analysis
# Let's see how our data looks like

# %%
df.count()
# Out:
# _id                 289981
# ageRange            289981
# idplug_base         289981
# idplug_station      289981
# idunplug_base       289981
# idunplug_station    289981
# track                87788
# travel_time         289981
# unplug_hourTime     289981
# user_day_code       289981
# user_type           289981
# zip_code            289981
# dtype: int64

# %% [markdown]
# We see almost 290.000 bike travels recorded, but only ~87.000 of them contain GPS route information.

# %% [markdown]
# ### 2.1 Travel times
# For how long do usually people use a bike? Are there extreme values? Why?
# Do different groups of people use bikes for different time? (for example: do tourists use bikes for longer periods of time?)

# %% [markdown]
# First of all, we're gonna need to convert travel times from seconds to minutes to better understand the measurements.

# %%
df['travel_time_mins'] = df['travel_time']/60

# %%
df['travel_time_mins'].describe()
# Out:
# count    289981.000000
# mean         18.274778
# std          89.918454
# min           0.000000
# 25%           6.350000
# 50%          10.650000
# 75%          16.833333
# max        9735.966667
# Name: travel_time_mins, dtype: float64

# %% [markdown]
# Okay, people usually take bikes for around 18 minutes, which is pretty normal. The standard deviation is very high and there seems to be some extreme values (max=9735min, that's almost 7 days! – probably a stolen/lost bike? It'd be awesome to analyze that GPS track!)
#
# Let's do a log transformation to nullify the effects of extreme values and plot it:

# %%
#We need to get rid of zero values first, to avoid divide by zero errors
df_nonzero_travel_times = df.loc[df['travel_time_mins'] > 0]

df['travel_time_mins_log'] = np.log(df_nonzero_travel_times['travel_time_mins'])

# %%
df['travel_time_mins_log'].hist(bins=250)

# %% [markdown]
# Okay, let's try to visualize the data to see our outliers. First of all, lets try to plot them all in a boxplot and see the distribution:

# %%
df_non_extreme_travel_times = df.loc[df['travel_time_mins'] > 0]
df_non_extreme_travel_times.boxplot(column='travel_time_mins')

# %% [markdown]
# Wow shit, that's some extreme values. Our data is not symmetrical at all. Look at those outliers above 6.000 minutes – that's almost 4 days using a bike! (yup, probably lost or stolen)

# %%
df_non_extreme_travel_times = df.loc[df['travel_time_mins'] > 6000]
df_non_extreme_travel_times['travel_time_mins'].count()
# Out:
# 15

# %% [markdown]
# So there's only 15 bikes that were used for more than 6000 minutes

# %%
df_non_extreme_travel_times = df.loc[df['travel_time_mins'] > 360]
df_non_extreme_travel_times['travel_time_mins'].count()
# Out:
# 236

# %% [markdown]
# And only 236 bikes that were used for more than 360 minutes (6 hours). So, let's remove extreme values and boxplot travels of less than 60 minutes (we're just "loosing" about 5% of the data, which are extreme outliers):

# %%
df_non_extreme_travel_times = df.loc[df['travel_time_mins'] < 60]
df_non_extreme_travel_times.boxplot(column='travel_time_mins')

# %% [markdown]
# Okay, that's better. Now we can even see the box. As discovered before, most users take a bike for around 5-15 minutes, and we can consider outliers travels of more than 30 minutes. How many outliers are there then and what percentage of the data do they represent?

# %%
df_non_extreme_travel_times = df.loc[df['travel_time_mins'] > 30]
df_non_extreme_travel_times['travel_time_mins'].count()
# Out:
# 29175

# %%
df_non_extreme_travel_times['travel_time_mins'].count() / df['travel_time_mins'].count()
# Out:
# 0.10061003996813585

# %% [markdown]
# Outliers (travels > 30min): 29175, that's about 10% of the data.

# %% [markdown]
# #### Travel times by user type
# Do different users behave differently?
#
# Let's recall from the docs:
# ```
# user_type = 0: undetermined
# user_type = 1: annual pass holder
# user_type = 2: occasional user (incl. tourists, I guess)
# user_type = 3: BiciMad employee
# ```

# %%
df.groupby(['user_type'])['travel_time_mins'].describe()
# Out:
# user_type
# 0          count      7375.000000
#            mean         30.862405
#            std          41.412250
#            min           0.033333
#            25%           7.700000
#            50%          15.750000
#            75%          37.608333
#            max         358.766667
# 1          count    247605.000000
#            mean         14.612580
#            std          22.656685
#            min           0.000000
#            25%           6.666667
#            50%          10.416667
#            75%          15.466667
#            max         359.883333
# 2          count      3025.000000
#            mean         40.599851
#            std          44.844825
#            min           0.033333
#            25%          10.900000
#            50%          24.166667
#            75%          56.666667
#            max         349.983333
# 3          count     31962.000000
#            mean         41.632729
#            std         260.885889
#            min           0.016667
#            25%           0.250000
#            50%          16.141667
#            75%          39.845833
#            max        9735.966667
# 4          count        14.000000
#            mean          7.164286
#            std          20.588785
#            min           0.083333
#            25%           0.583333
#            50%           1.008333
#            75%           2.941667
#            max          78.483333
# Name: travel_time_mins, dtype: float64

# %% [markdown]
# We see a number of things.
#
# First of all, there's a user_type = 4 that's not documented. Don't know who are those, but they account for more than 3% of the dataset (almost 10k bike travels)
#
# Secondly, there's a **huge** difference between occasional users and regular users. While regular users take bikes for about 15 minutes (with a low std deviation), occasional users use bikes for considerably longer periods: about 40 minutes (and high 44 std dvt). This could mean occasional users are mostly tourists that use bikes for sightseeing and relaxed travels around the city. To be confirmed with GPS data.
#
# Now, look at those BiciMad employee numbers – that's where the outliers come from! It was not stolen/lost bikes, it was probably bikes under maintenance!
#
#
# On with our next question: do users with different age behave in different ways?

# %%
df.groupby(['user_type', 'ageRange'])['travel_time_mins'].describe()
# Out:
# user_type  ageRange
# 0          0         count     7375.000000
#                      mean        30.862405
#                      std         41.412250
#                      min          0.033333
#                      25%          7.700000
#                      50%         15.750000
#                      75%         37.608333
#                      max        358.766667
# 1          0         count     2325.000000
#                      mean        20.198050
#                      std         32.583063
#                      min          0.033333
#                      25%          7.333333
#                      50%         12.200000
#                      75%         19.800000
#                      max        357.916667
#            1         count     2262.000000
#                      mean        15.109859
#                      std         22.537625
#                      min          0.033333
#                      25%          5.504167
#                      50%          9.616667
#                      75%         15.762500
#                      max        346.833333
#            2         count     6029.000000
#                      mean        16.057254
#                      std         24.950832
#                      min          0.033333
#                      25%          6.166667
#                      50%         10.183333
#                                   ...
# 3          3         std         71.750765
#                      min          0.033333
#                      25%          0.166667
#                      50%          0.283333
#                      75%         18.658333
#                      max       3576.200000
#            4         count    17418.000000
#                      mean        54.759297
#                      std        316.503157
#                      min          0.033333
#                      25%          9.137500
#                      50%         24.808333
#                      75%         46.333333
#                      max       9735.966667
#            5         count     3789.000000
#                      mean        49.525873
#                      std        215.825861
#                      min          0.033333
#                      25%          0.450000
#                      50%         23.600000
#                      75%         50.316667
#                      max       5016.800000
# 4          5         count       14.000000
#                      mean         7.164286
#                      std         20.588785
#                      min          0.083333
#                      25%          0.583333
#                      50%          1.008333
#                      75%          2.941667
#                      max         78.483333
# Name: travel_time_mins, dtype: float64

# %% [markdown]
# #### Popular hours

# %% [markdown]
# #### Popular hours by station per day

# %% [markdown]
# ---

# %% [markdown]
# ## Most popular stations
# Which are the most popular stations? Which are mainly used for taking bikes and which are mainly used to return bikes? Are there any popular travels between 2 stations?

# %%
df['idunplug_station'].value_counts()
# Out:
# 43      4217
# 57      4085
# 129     3869
# 163     3809
# 64      3705
# 135     3513
# 90      3272
# 108     3127
# 168     3037
# 160     2968
# 162     2951
# 45      2924
# 132     2875
# 149     2787
# 83      2756
# 58      2751
# 161     2740
# 49      2739
# 9       2714
# 128     2712
# 23      2668
# 1       2582
# 79      2563
# 78      2454
# 170     2446
# 38      2432
# 74      2420
# 113     2333
# 59      2314
# 166     2284
#         ...
# 21      1025
# 159     1004
# 152      990
# 151      987
# 101      977
# 165      962
# 105      953
# 111      945
# 141      929
# 104      906
# 36       898
# 61       896
# 138      876
# 144      869
# 107      861
# 98       858
# 22       857
# 97       854
# 147      837
# 120      759
# 24       714
# 173      693
# 88       649
# 37       633
# 150      625
# 29       615
# 60       531
# 28       505
# 119      436
# 2008      37
# Name: idunplug_station, dtype: int64

# %%
df['idplug_station'].value_counts()
# Out:
# 43      4386
# 57      4044
# 129     3943
# 163     3898
# 135     3721
# 64      3696
# 90      3260
# 168     3154
# 108     3062
# 160     3060
# 162     3027
# 45      3000
# 132     2986
# 49      2794
# 83      2780
# 161     2768
# 9       2763
# 149     2762
# 58      2753
# 128     2724
# 23      2638
# 1       2543
# 79      2502
# 78      2481
# 170     2449
# 74      2423
# 38      2418
# 133     2360
# 59      2316
# 166     2298
#         ...
# 165     1008
# 127      996
# 159      992
# 151      969
# 101      946
# 152      943
# 105      906
# 104      892
# 36       892
# 141      886
# 61       881
# 111      875
# 138      853
# 107      853
# 98       850
# 22       849
# 97       848
# 147      847
# 144      830
# 120      781
# 24       697
# 173      692
# 88       627
# 150      607
# 37       607
# 29       590
# 60       524
# 28       470
# 119      425
# 2008      38
# Name: idplug_station, dtype: int64

# %% [markdown]
# ### GPS tracks analysis

# %%
# Lets filter our DataFrame and get a DataFrame only with entries containing a not-NaN "track" property
df_track = df.loc[df.track.notnull()]

# %% [markdown]
# Unfortunately, the GeoJSON stored by BiciMad is not in a valid GeoJSON format :(
#
#  - Single quotes `(')` should be double quotes `(")`
#  - A `FeatureCollection` GeoJSON should be of this form:
#     ```
#     { "type": "FeatureCollection",
#       "features": [
#       .
#       .
#       .
#      ]}
#     ```
#     Instead of:
#     ```
#     {'FeatureCollection':
#         {'Features': [
#         ]}
#     }
#     ```
#  - The `features` property should be lowercase
#
# Useful links:
#  - [GeoJSON specification (RFC7946)](https://tools.ietf.org/html/rfc7946)
#  - [Online GeoJSON linter, validator & viewer](http://geojsonlint.com)

# %%
df_track
# Out:
#                                          _id  ageRange  idplug_base  \
# 115348  {'$oid': '58d18956865e9c3790a34a04'}         4           21
# 117252  {'$oid': '58d1a814865e9c1d0415cd52'}         1            2
# 129814  {'$oid': '58d181be865e9c3790a32858'}         5            7
# 130571  {'$oid': '58d181be865e9c3790a32857'}         4           22
# 130574  {'$oid': '58d181e8865e9c3790a32901'}         4            5
# 131154  {'$oid': '58d181f0865e9c3790a32925'}         3           10
# 131156  {'$oid': '58d181f5865e9c3790a3293c'}         4            9
# 131500  {'$oid': '58d181c3865e9c3790a3286b'}         4           20
# 131813  {'$oid': '58d181b7865e9c3790a3283c'}         4           24
# 131814  {'$oid': '58d181b8865e9c3790a32841'}         3           15
# 131815  {'$oid': '58d181bb865e9c3790a32849'}         5            7
# 131816  {'$oid': '58d181bd865e9c3790a3284f'}         4           18
# 131817  {'$oid': '58d181be865e9c3790a32855'}         5            6
# 131819  {'$oid': '58d181bf865e9c3790a32859'}         5           10
# 131820  {'$oid': '58d181bf865e9c3790a3285a'}         5            9
# 131821  {'$oid': '58d181c1865e9c3790a32860'}         3            3
# 131822  {'$oid': '58d181c1865e9c3790a32861'}         4            7
# 131825  {'$oid': '58d181c2865e9c3790a32866'}         5           13
# 131826  {'$oid': '58d181c2865e9c3790a32867'}         5           12
# 131829  {'$oid': '58d181c4865e9c3790a3286c'}         5           19
# 131832  {'$oid': '58d181d9865e9c3790a328bf'}         4           16
# 131833  {'$oid': '58d181d9865e9c3790a328c1'}         4           20
# 131836  {'$oid': '58d181f4865e9c3790a3293a'}         5            7
# 132025  {'$oid': '58d181b7865e9c3790a3283d'}         2            5
# 132028  {'$oid': '58d181b8865e9c3790a32840'}         5           21
# 132029  {'$oid': '58d181b9865e9c3790a32842'}         4            4
# 132031  {'$oid': '58d181b9865e9c3790a32844'}         5            4
# 132033  {'$oid': '58d181ba865e9c3790a32846'}         3           11
# 132035  {'$oid': '58d181ba865e9c3790a32848'}         5           10
# 132036  {'$oid': '58d181bb865e9c3790a3284a'}         4            4
# ...                                      ...       ...          ...
# 289932  {'$oid': '58e5e616865e9c221ca47961'}         4            3
# 289934  {'$oid': '58e5e616865e9c221ca47963'}         4            9
# 289936  {'$oid': '58e5e616865e9c221ca47965'}         0           22
# 289937  {'$oid': '58e5e616865e9c221ca47966'}         3            1
# 289938  {'$oid': '58e5e616865e9c221ca47967'}         3            5
# 289939  {'$oid': '58e5e616865e9c221ca47968'}         3           10
# 289941  {'$oid': '58e5e616865e9c221ca47969'}         0            4
# 289942  {'$oid': '58e5e616865e9c221ca4796b'}         3            4
# 289943  {'$oid': '58e5e616865e9c221ca4796c'}         4           17
# 289945  {'$oid': '58e5e616865e9c221ca4796e'}         4            9
# 289948  {'$oid': '58e5e616865e9c221ca47971'}         0           18
# 289949  {'$oid': '58e5e616865e9c221ca47972'}         4           15
# 289950  {'$oid': '58e5e616865e9c221ca47973'}         4           14
# 289951  {'$oid': '58e5e616865e9c221ca47974'}         4           23
# 289952  {'$oid': '58e5e616865e9c221ca47975'}         3            3
# 289953  {'$oid': '58e5e616865e9c221ca47976'}         3            5
# 289957  {'$oid': '58e5e616865e9c221ca4797a'}         3            1
# 289958  {'$oid': '58e5e616865e9c221ca4797b'}         0           16
# 289959  {'$oid': '58e5e616865e9c221ca4797c'}         5            4
# 289962  {'$oid': '58e5e616865e9c221ca47980'}         4            4
# 289963  {'$oid': '58e5e616865e9c221ca47981'}         4            4
# 289964  {'$oid': '58e5e616865e9c221ca47982'}         5           22
# 289965  {'$oid': '58e5e616865e9c221ca47983'}         4            7
# 289966  {'$oid': '58e5e616865e9c221ca47984'}         5           24
# 289967  {'$oid': '58e5e616865e9c221ca47985'}         5            2
# 289971  {'$oid': '58e5e616865e9c221ca47989'}         4            1
# 289973  {'$oid': '58e5e616865e9c221ca4798b'}         3            1
# 289974  {'$oid': '58e5e616865e9c221ca4798c'}         4           24
# 289976  {'$oid': '58e5e616865e9c221ca4798e'}         3            8
# 289980  {'$oid': '58e5e616865e9c221ca47993'}         4            2
#
#         idplug_station  idunplug_base  idunplug_station  \
# 115348              60             10                19
# 117252              71             15               132
# 129814              36              2                36
# 130571              13             22                13
# 130574              49             10                40
# 131154             121              4               149
# 131156             160              9                19
# 131500               1             11                77
# 131813              29             23               149
# 131814             137              4                43
# 131815             133              4               134
# 131816             149             15                23
# 131817             107             10               133
# 131819             107             13               133
# 131820             107              3                52
# 131821             142              9                96
# 131822              73             16                84
# 131825              73             23                52
# 131826              73             19                52
# 131829              73              9                52
# 131832              23             12                48
# 131833              23             11                48
# 131836             172              3               137
# 132025              35              7               135
# 132028              10              6                48
# 132029             135              9               165
# 132031             134             16                27
# 132033             128             21                62
# 132035             163             18               166
# 132036              90             24                19
# ...                ...            ...               ...
# 289932               3              2                74
# 289934             135             17                26
# 289936              59             11                19
# 289937             163             19                58
# 289938             157             14               130
# 289939             142              9                10
# 289941             142             13                10
# 289942              46              6                57
# 289943              87             21                56
# 289945             136             16                79
# 289948              98              3                38
# 289949              49              1                26
# 289950             168             22                35
# 289951             129              4                46
# 289952              43              2                57
# 289953              71              1                27
# 289957              38              2               125
# 289958             172              6               146
# 289959             166              5                96
# 289962             156              4               142
# 289963             174             24                57
# 289964              79              6                45
# 289965             174             15                57
# 289966              79              2                45
# 289967              23              4                 5
# 289971              43             23                47
# 289973              16             21               117
# 289974             135              6                59
# 289976              45             21                26
# 289980              32             21                90
#
#                                                     track  travel_time  \
# 115348  {'FeatureCollection': {'Features': [{'properti...       156725
# 117252  {'FeatureCollection': {'Features': [{'properti...       261831
# 129814  {'FeatureCollection': {'Features': [{'properti...        18887
# 130571  {'FeatureCollection': {'Features': [{'properti...        12680
# 130574  {'FeatureCollection': {'Features': [{'properti...        18043
# 131154  {'FeatureCollection': {'Features': [{'properti...        15125
# 131156  {'FeatureCollection': {'Features': [{'properti...        17864
# 131500  {'FeatureCollection': {'Features': [{'properti...         6859
# 131813  {'FeatureCollection': {'Features': [{'properti...         1853
# 131814  {'FeatureCollection': {'Features': [{'properti...         1690
# 131815  {'FeatureCollection': {'Features': [{'properti...         3233
# 131816  {'FeatureCollection': {'Features': [{'properti...         1881
# 131817  {'FeatureCollection': {'Features': [{'properti...         2002
# 131819  {'FeatureCollection': {'Features': [{'properti...         2169
# 131820  {'FeatureCollection': {'Features': [{'properti...         2790
# 131821  {'FeatureCollection': {'Features': [{'properti...         2041
# 131822  {'FeatureCollection': {'Features': [{'properti...         5234
# 131825  {'FeatureCollection': {'Features': [{'properti...         3632
# 131826  {'FeatureCollection': {'Features': [{'properti...         3717
# 131829  {'FeatureCollection': {'Features': [{'properti...         3851
# 131832  {'FeatureCollection': {'Features': [{'properti...         5009
# 131833  {'FeatureCollection': {'Features': [{'properti...         5081
# 131836  {'FeatureCollection': {'Features': [{'properti...        11854
# 132025  {'FeatureCollection': {'Features': [{'properti...          622
# 132028  {'FeatureCollection': {'Features': [{'properti...          316
# 132029  {'FeatureCollection': {'Features': [{'properti...          966
# 132031  {'FeatureCollection': {'Features': [{'properti...          397
# 132033  {'FeatureCollection': {'Features': [{'properti...          553
# 132035  {'FeatureCollection': {'Features': [{'properti...          418
# 132036  {'FeatureCollection': {'Features': [{'properti...          858
# ...                                                   ...          ...
# 289932  {'FeatureCollection': {'Features': [{'properti...          715
# 289934  {'FeatureCollection': {'Features': [{'properti...          970
# 289936  {'FeatureCollection': {'Features': [{'properti...          279
# 289937  {'FeatureCollection': {'Features': [{'properti...          233
# 289938  {'FeatureCollection': {'Features': [{'properti...          403
# 289939  {'FeatureCollection': {'Features': [{'properti...         1390
# 289941  {'FeatureCollection': {'Features': [{'properti...         1413
# 289942  {'FeatureCollection': {'Features': [{'properti...         2321
# 289943  {'FeatureCollection': {'Features': [{'properti...          618
# 289945  {'FeatureCollection': {'Features': [{'properti...          664
# 289948  {'FeatureCollection': {'Features': [{'properti...          833
# 289949  {'FeatureCollection': {'Features': [{'properti...          574
# 289950  {'FeatureCollection': {'Features': [{'properti...          726
# 289951  {'FeatureCollection': {'Features': [{'properti...          308
# 289952  {'FeatureCollection': {'Features': [{'properti...          338
# 289953  {'FeatureCollection': {'Features': [{'properti...          439
# 289957  {'FeatureCollection': {'Features': [{'properti...          791
# 289958  {'FeatureCollection': {'Features': [{'properti...          310
# 289959  {'FeatureCollection': {'Features': [{'properti...          410
# 289962  {'FeatureCollection': {'Features': [{'properti...          402
# 289963  {'FeatureCollection': {'Features': [{'properti...         1571
# 289964  {'FeatureCollection': {'Features': [{'properti...          927
# 289965  {'FeatureCollection': {'Features': [{'properti...         1539
# 289966  {'FeatureCollection': {'Features': [{'properti...          923
# 289967  {'FeatureCollection': {'Features': [{'properti...          313
# 289971  {'FeatureCollection': {'Features': [{'properti...          270
# 289973  {'FeatureCollection': {'Features': [{'properti...          385
# 289974  {'FeatureCollection': {'Features': [{'properti...         1263
# 289976  {'FeatureCollection': {'Features': [{'properti...          432
# 289980  {'FeatureCollection': {'Features': [{'properti...          375
#
#                                   unplug_hourTime  \
# 115348  {'$date': '2017-03-13T12:00:00.000+0100'}
# 117252  {'$date': '2017-03-13T16:00:00.000+0100'}
# 129814  {'$date': '2017-03-14T20:00:00.000+0100'}
# 130571  {'$date': '2017-03-14T21:00:00.000+0100'}
# 130574  {'$date': '2017-03-14T21:00:00.000+0100'}
# 131154  {'$date': '2017-03-14T22:00:00.000+0100'}
# 131156  {'$date': '2017-03-14T22:00:00.000+0100'}
# 131500  {'$date': '2017-03-14T23:00:00.000+0100'}
# 131813  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131814  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131815  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131816  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131817  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131819  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131820  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131821  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131822  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131825  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131826  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131829  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131832  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131833  {'$date': '2017-03-15T00:00:00.000+0100'}
# 131836  {'$date': '2017-03-15T00:00:00.000+0100'}
# 132025  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132028  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132029  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132031  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132033  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132035  {'$date': '2017-03-15T01:00:00.000+0100'}
# 132036  {'$date': '2017-03-15T01:00:00.000+0100'}
# ...                                           ...
# 289932  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289934  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289936  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289937  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289938  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289939  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289941  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289942  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289943  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289945  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289948  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289949  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289950  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289951  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289952  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289953  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289957  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289958  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289959  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289962  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289963  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289964  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289965  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289966  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289967  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289971  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289973  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289974  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289976  {'$date': '2017-04-01T22:00:00.000+0100'}
# 289980  {'$date': '2017-04-01T22:00:00.000+0100'}
#
#                                             user_day_code  user_type zip_code  \
# 115348  fce2be1e9634cbcf37fc6898d12d0dff8732ac0b159f07...          3
# 117252  ba8ccf63ccc66fc4c28adc621bcc15a3a70286ab3a2480...          3
# 129814  1c15cc8e667946f44f0a07aaaf529d3737527d04f1c6b4...          1    28009
# 130571  33287e1807327a243dc12ee4d297ef8f56940992257c63...          1    28005
# 130574  ea67a1693aabf82860de4c3eda49ea95dd0939e17b3d21...          1    28047
# 131154  0e203142eb42fa7178db31ec80aba50695d3408c2872ba...          1    28008
# 131156  8ad7e45dc1603c71cd29397bec6fd0cbe785d3de791ff7...          1    28004
# 131500  3ec89a8148c0b835cace234fcc38ddd3a2561d1068a3f4...          3
# 131813  2a192bd4ccebe687f6af157215a528f0c549f0e603455b...          1    28005
# 131814  5e0c3f0a0ccc690c35de9056c24afc44e0f7702cb0c8f4...          1    28026
# 131815  2f3ef37491dfe54d94c8d9f1769cd279f5beca9928278e...          1    28005
# 131816  fac0c9ae633ef056a83f5f059d8ce1f21c383cdf2f4d58...          1    28003
# 131817  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131819  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131820  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131821  7f12fe2dce0bd9b2166de102dbef4b0778a5d245726fb8...          1    28008
# 131822  796d4b092c124ce6637ccb312b285311e235a54fd220b6...          1    28009
# 131825  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131826  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131829  5c101071f1d4a0b4f051df8442e892813b75c81d225715...          3
# 131832  3ec89a8148c0b835cace234fcc38ddd3a2561d1068a3f4...          3
# 131833  3ec89a8148c0b835cace234fcc38ddd3a2561d1068a3f4...          3
# 131836  ab298853eac5935d6e45379bea32adb719df3a661909f6...          1    28012
# 132025  d8c80d538f1c51a3369c701457211a79055ab8efe84e06...          1    28045
# 132028  3984c4a5d50116ec9872c130280d64cf1ed566d94a843d...          1    28013
# 132029  cd4104076c3c92de73249b9e90802d32db01bd91a53992...          1    28041
# 132031  b0867a73aaa887f64ea4280c07e70468d54c583705f3f1...          1
# 132033  9f1d35465294d18841f497b9ef65abe585f8a0f3cbf09d...          1    28004
# 132035  434d0a030d6361c002ffd40167298ae5b4eec603e3af9b...          1    28010
# 132036  75e8700c6e5bd1efec25ca9b695e837455f66cf06a9436...          1    28009
# ...                                                   ...        ...      ...
# 289932  b2ef0d968642828ba5d3e12fc9843da8c56660bcd5ebab...          1    28009
# 289934  ef8e10f209ae410fa5bda790132ebd9c1532f2392da579...          1    28045
# 289936  220dfb5c0c0598a93350acec32cf5453f2c2d781948ce1...          0
# 289937  a51d4667b643a037dead34526984a618d91550a8d8ee39...          1    28004
# 289938  e505a0a3bdbf1e2d8897974d70623dd9f428affcc773c8...          1    28015
# 289939  add433bd2a4fc9907b4d91a6438d0c33864a59dd872d7f...          1    28020
# 289941  31b3a715a08254240bef14f7870a7b42fee01a0f16da26...          0
# 289942  264f1fd07aa6a09d1b6d700bb12b4a5668aa1a73f71857...          1    28012
# 289943  32502419c70f57d1804a67b3123dcfde16faff8a6090d0...          1    28007
# 289945  81a240a0b0e44234467e4b0a339d6a0f72a3d7df782f86...          1    28014
# 289948  f5855808a76ba192bff5f58c88b60bd4046e00d83098c8...          0
# 289949  370328a250de3a6cbaba7f922a1882fc9b44f7f3d1d222...          1    03680
# 289950  10b393e2380e38ccb0d124831230302f988e9a2e7cc832...          1    28015
# 289951  7bdc628e79807786937776956301d3b099bed8e190ddae...          1    28012
# 289952  f74f3466116304667b42e8df94842ad9b0e6c9a2683cbb...          1    28012
# 289953  e55feef66ca09bf8335227d303eb20ba516179dcbd3098...          1    28013
# 289957  55a1dde0d51ef0098b990f45a8331b559b58f7a197d4b8...          1    28008
# 289958  ec3bf64db8dcc61331a4f0b360d2fb942cfe0ee56a80bd...          0
# 289959  feb4e523dd8bdaed99a086e02c799b14d10dac34f4d957...          1    28006
# 289962  7471b559470ac9c115db40a361e3c4e28d8dcfe0023ecf...          1    28020
# 289963  fc89c0a887e5dc9424259e68e737cdb67fde60c0158aef...          1    28012
# 289964  3b1f9f91e0194213409a23f4a58a065871e539e8505514...          1    28007
# 289965  5e6d144ba80275898265ed580b742111b6e6b06c65e9aa...          1    28012
# 289966  97aa3a0552ed415e3fe56398a1aeed0c6004fc2c33d5ab...          1    28007
# 289967  7f9d5f10a1bdc65187778658a562310624a1d35717677d...          1    28010
# 289971  4e4353dbc7cd56a8b4760e61df8b23ba93a2f68f8132c5...          1    28005
# 289973  3ef2414f61641985c65b3a447f35e6017741ae698f5fb2...          1    28006
# 289974  ad10cf2263701c272a1191fb5fb81fbc3490d017ffee05...          1    28045
# 289976  ed0eee7b71b57bae149c9dce6ea368d06e3cd666050a85...          1    28024
# 289980  0580d62266cb3c4753b665211f467574747ab36c33e94a...          1    28009
#
#         travel_time_log  travel_time_mins  travel_time_mins_log
# 115348        11.962248       2612.083333              7.867903
# 117252        12.475455       4363.850000              8.381110
# 129814         9.846229        314.783333              5.751885
# 130571         9.447781        211.333333              5.353437
# 130574         9.800513        300.716667              5.706169
# 131154         9.624104        252.083333              5.529760
# 131156         9.790543        297.733333              5.696198
# 131500         8.833317        114.316667              4.738972
# 131813         7.524561         30.883333              3.430217
# 131814         7.432484         28.166667              3.338139
# 131815         8.081166         53.883333              3.986821
# 131816         7.539559         31.350000              3.445214
# 131817         7.601902         33.366667              3.507557
# 131819         7.682022         36.150000              3.587677
# 131820         7.933797         46.500000              3.839452
# 131821         7.621195         34.016667              3.526851
# 131822         8.562931         87.233333              4.468587
# 131825         8.197539         60.533333              4.103194
# 131826         8.220672         61.950000              4.126328
# 131829         8.256088         64.183333              4.161744
# 131832         8.518992         83.483333              4.424647
# 131833         8.533263         84.683333              4.438919
# 131836         9.380421        197.566667              5.286076
# 132025         6.432940         10.366667              2.338596
# 132028         5.755742          5.266667              1.661398
# 132029         6.873164         16.100000              2.778819
# 132031         5.983936          6.616667              1.889592
# 132033         6.315358          9.216667              2.221013
# 132035         6.035481          6.966667              1.941137
# 132036         6.754604         14.300000              2.660260
# ...                 ...               ...                   ...
# 289932         6.572283         11.916667              2.477938
# 289934         6.877296         16.166667              2.782952
# 289936         5.631212          4.650000              1.536867
# 289937         5.451038          3.883333              1.356694
# 289938         5.998937          6.716667              1.904592
# 289939         7.237059         23.166667              3.142714
# 289941         7.253470         23.550000              3.159126
# 289942         7.749753         38.683333              3.655409
# 289943         6.426488         10.300000              2.332144
# 289945         6.498282         11.066667              2.403938
# 289948         6.725034         13.883333              2.630689
# 289949         6.352629          9.566667              2.258285
# 289950         6.587550         12.100000              2.493205
# 289951         5.730100          5.133333              1.635755
# 289952         5.823046          5.633333              1.728701
# 289953         6.084499          7.316667              1.990155
# 289957         6.673298         13.183333              2.578953
# 289958         5.736572          5.166667              1.642228
# 289959         6.016157          6.833333              1.921813
# 289962         5.996452          6.700000              1.902108
# 289963         7.359468         26.183333              3.265123
# 289964         6.831954         15.450000              2.737609
# 289965         7.338888         25.650000              3.244544
# 289966         6.827629         15.383333              2.733285
# 289967         5.746203          5.216667              1.651859
# 289971         5.598422          4.500000              1.504077
# 289973         5.953243          6.416667              1.858899
# 289974         7.141245         21.050000              3.046901
# 289976         6.068426          7.200000              1.974081
# 289980         5.926926          6.250000              1.832581
#
# [87788 rows x 15 columns]

# %%
df_track.loc[df_track['travel_time_mins'] > 3000]
# Out:
#                                          _id  ageRange  idplug_base  \
# 117252  {'$oid': '58d1a814865e9c1d0415cd52'}         1            2
# 132725  {'$oid': '58d6f6a5865e9c36b475effb'}         4            1
# 143097  {'$oid': '58d5a52d865e9c338c190ee7'}         4           16
# 145025  {'$oid': '58d6f69c865e9c36b475ebd0'}         4            5
# 147075  {'$oid': '58d45390865e9c36145751eb'}         4           12
# 148394  {'$oid': '58db519c865e9c19b8b3dffd'}         4            9
# 155449  {'$oid': '58d5a52e865e9c338c190f35'}         5            5
# 155603  {'$oid': '58d45390865e9c36145751db'}         4           17
# 158907  {'$oid': '58db519a865e9c19b8b3df72'}         4            8
# 158909  {'$oid': '58db519c865e9c19b8b3dffb'}         4           10
# 166176  {'$oid': '58db51c4865e9c19b8b3f925'}         4           12
# 172354  {'$oid': '58d83a0d865e9c108048a22a'}         5           11
# 173371  {'$oid': '58d83a0e865e9c108048a297'}         4            8
# 180385  {'$oid': '58d83a3c865e9c108048b993'}         4           27
# 191427  {'$oid': '58db51c5865e9c19b8b3f9d8'}         4            9
# 207445  {'$oid': '58ddf403865e9c1f086f1bf0'}         5           14
# 210757  {'$oid': '58e1f3d9865e9c1bdc06a53e'}         4           19
# 213586  {'$oid': '58e1f3dc865e9c1bdc06a713'}         1           15
# 213587  {'$oid': '58e1f3ec865e9c1bdc06b1dd'}         1           20
# 213588  {'$oid': '58e1f3ee865e9c1bdc06b361'}         1            4
# 213907  {'$oid': '58e1f3dd865e9c1bdc06a80a'}         4            1
# 218687  {'$oid': '58e1f3dc865e9c1bdc06a76f'}         4           20
# 218688  {'$oid': '58e1f3dc865e9c1bdc06a778'}         4           16
# 218689  {'$oid': '58e1f3dc865e9c1bdc06a77f'}         4           14
# 218690  {'$oid': '58e1f3dc865e9c1bdc06a783'}         4           12
# 218791  {'$oid': '58e1f3dc865e9c1bdc06a6f8'}         4           17
# 218794  {'$oid': '58e1f3dc865e9c1bdc06a705'}         4           11
# 223266  {'$oid': '58e1f3db865e9c1bdc06a6ef'}         5           15
# 223269  {'$oid': '58e1f3dc865e9c1bdc06a722'}         5           21
# 238852  {'$oid': '58e3424e865e9c240406a962'}         5           17
#
#         idplug_station  idunplug_base  idunplug_station  \
# 117252              71             15               132
# 132725            2008              5                79
# 143097             133              5                67
# 145025              79              5                82
# 147075             145             16                95
# 148394              83             19               132
# 155449             159             18               135
# 155603             145              5               151
# 158907              79              8               112
# 158909              83              1               111
# 166176              79              8                19
# 172354             129             12                57
# 173371             128             10               163
# 180385             102             12               137
# 191427             129             14                90
# 207445               6              4               162
# 210757              28             16               132
# 213586              56              9               108
# 213587              38             13               108
# 213588             144             12               108
# 213907               3             19               120
# 218687              38             17                49
# 218688              38             16                49
# 218689              38              9                49
# 218690              38             12                49
# 218791             127             17               149
# 218794             127             10                73
# 223266             127             11                38
# 223269              56             22                38
# 238852             108              6                34
#
#                                                     track  travel_time  \
# 117252  {'FeatureCollection': {'Features': [{'properti...       261831
# 132725  {'FeatureCollection': {'Features': [{'properti...       522803
# 143097  {'FeatureCollection': {'Features': [{'properti...       402740
# 145025  {'FeatureCollection': {'Features': [{'properti...       427285
# 147075  {'FeatureCollection': {'Features': [{'properti...       242053
# 148394  {'FeatureCollection': {'Features': [{'properti...       584055
# 155449  {'FeatureCollection': {'Features': [{'properti...       301008
# 155603  {'FeatureCollection': {'Features': [{'properti...       180223
# 158907  {'FeatureCollection': {'Features': [{'properti...       500632
# 158909  {'FeatureCollection': {'Features': [{'properti...       501398
# 166176  {'FeatureCollection': {'Features': [{'properti...       517185
# 172354  {'FeatureCollection': {'Features': [{'properti...       287879
# 173371  {'FeatureCollection': {'Features': [{'properti...       272365
# 180385  {'FeatureCollection': {'Features': [{'properti...       221707
# 191427  {'FeatureCollection': {'Features': [{'properti...       239463
# 207445  {'FeatureCollection': {'Features': [{'properti...       240932
# 210757  {'FeatureCollection': {'Features': [{'properti...       347624
# 213586  {'FeatureCollection': {'Features': [{'properti...       324651
# 213587  {'FeatureCollection': {'Features': [{'properti...       342724
# 213588  {'FeatureCollection': {'Features': [{'properti...       345882
# 213907  {'FeatureCollection': {'Features': [{'properti...       325168
# 218687  {'FeatureCollection': {'Features': [{'properti...       263573
# 218688  {'FeatureCollection': {'Features': [{'properti...       263577
# 218689  {'FeatureCollection': {'Features': [{'properti...       263526
# 218690  {'FeatureCollection': {'Features': [{'properti...       263596
# 218791  {'FeatureCollection': {'Features': [{'properti...       261855
# 218794  {'FeatureCollection': {'Features': [{'properti...       261354
# 223266  {'FeatureCollection': {'Features': [{'properti...       204415
# 223269  {'FeatureCollection': {'Features': [{'properti...       204466
# 238852  {'FeatureCollection': {'Features': [{'properti...       198578
#
#                                   unplug_hourTime  \
# 117252  {'$date': '2017-03-13T16:00:00.000+0100'}
# 132725  {'$date': '2017-03-15T08:00:00.000+0100'}
# 143097  {'$date': '2017-03-16T00:00:00.000+0100'}
# 145025  {'$date': '2017-03-16T09:00:00.000+0100'}
# 147075  {'$date': '2017-03-16T13:00:00.000+0100'}
# 148394  {'$date': '2017-03-16T14:00:00.000+0100'}
# 155449  {'$date': '2017-03-17T04:00:00.000+0100'}
# 155603  {'$date': '2017-03-17T06:00:00.000+0100'}
# 158907  {'$date': '2017-03-17T13:00:00.000+0100'}
# 158909  {'$date': '2017-03-17T13:00:00.000+0100'}
# 166176  {'$date': '2017-03-18T08:00:00.000+0100'}
# 172354  {'$date': '2017-03-19T00:00:00.000+0100'}
# 173371  {'$date': '2017-03-19T04:00:00.000+0100'}
# 180385  {'$date': '2017-03-20T07:00:00.000+0100'}
# 191427  {'$date': '2017-03-21T13:00:00.000+0100'}
# 207445  {'$date': '2017-03-23T12:00:00.000+0100'}
# 210757  {'$date': '2017-03-23T23:00:00.000+0100'}
# 213586  {'$date': '2017-03-24T12:00:00.000+0100'}
# 213587  {'$date': '2017-03-24T12:00:00.000+0100'}
# 213588  {'$date': '2017-03-24T12:00:00.000+0100'}
# 213907  {'$date': '2017-03-24T13:00:00.000+0100'}
# 218687  {'$date': '2017-03-25T05:00:00.000+0100'}
# 218688  {'$date': '2017-03-25T05:00:00.000+0100'}
# 218689  {'$date': '2017-03-25T05:00:00.000+0100'}
# 218690  {'$date': '2017-03-25T05:00:00.000+0100'}
# 218791  {'$date': '2017-03-25T06:00:00.000+0100'}
# 218794  {'$date': '2017-03-25T06:00:00.000+0100'}
# 223266  {'$date': '2017-03-25T22:00:00.000+0100'}
# 223269  {'$date': '2017-03-25T22:00:00.000+0100'}
# 238852  {'$date': '2017-03-28T07:00:00.000+0100'}
#
#                                             user_day_code  user_type zip_code  \
# 117252  ba8ccf63ccc66fc4c28adc621bcc15a3a70286ab3a2480...          3
# 132725  cb1821c93016b118cd051bbad7235e6ee02917c9e9802a...          3
# 143097  519360a2fb67b71612bd724597fa771b521de1faea0915...          3
# 145025  73eadbfecc7348c8a1d2b9e7e381ca0dfee3bd32c57d76...          3
# 147075  3bb1f648a0044033ce5666387c9d23e4b5663a83ccebc7...          3
# 148394  7cd44a7b5dabf6cd73e56eb263da528c0ea2721ff0baea...          3
# 155449  3d9162dd9783d1b8a027cea65d47887696a1e139f90bb0...          3
# 155603  7db26f4863f2c61236260121339f0e3395948f6d1789f0...          3
# 158907  1357ad462bc16d867d887476b5653aa2e02e9e42aa3c3c...          3
# 158909  1357ad462bc16d867d887476b5653aa2e02e9e42aa3c3c...          3
# 166176  45b4e7c8d432e64b19bc3b33ee13144b97ce5172636667...          3
# 172354  09d89b9b3e4157161a84783e72cbf85e29bf244c1dd0a7...          3
# 173371  dc38d618d57958cdfc15694129ef601c120d249bbc8e04...          3
# 180385  901347eabfebacb99a47202d299627b104aa5e02688445...          3
# 191427  45b4e7c8d432e64b19bc3b33ee13144b97ce5172636667...          3
# 207445  fcfe46f010bb936e1875363239f1a4335ef0ff7239bb4e...          3
# 210757  2cb77736513d79b38f23b4bd5c6b317cf1c73f7ab01657...          3
# 213586  ec190b6252b364a2ce13f8acdd1064d8fca207540f4296...          3
# 213587  ec190b6252b364a2ce13f8acdd1064d8fca207540f4296...          3
# 213588  ec190b6252b364a2ce13f8acdd1064d8fca207540f4296...          3
# 213907  5434561ed6710075d1fda02de21e5d0d0b85ff55622a29...          3
# 218687  b4670efaeff5bba50f6f32d0f8e6bdc91706527f38db8d...          3
# 218688  b4670efaeff5bba50f6f32d0f8e6bdc91706527f38db8d...          3
# 218689  b4670efaeff5bba50f6f32d0f8e6bdc91706527f38db8d...          3
# 218690  b4670efaeff5bba50f6f32d0f8e6bdc91706527f38db8d...          3
# 218791  bf28fb33de025085605415981dbd6171b3804bfea09116...          3
# 218794  eb599130176b767d9df8d090ca5c705b4ffae821c1fabc...          3
# 223266  9d0ebc719a0d7f8ad861cdc5e33dcf560322084df0d188...          3
# 223269  9d0ebc719a0d7f8ad861cdc5e33dcf560322084df0d188...          3
# 238852  4d8a62a67c9c339ba6a83ca82ad9857e10d59454f09fba...          3    28003
#
#         travel_time_log  travel_time_mins  travel_time_mins_log
# 117252        12.475455       4363.850000              8.381110
# 132725        13.166960       8713.383333              9.072615
# 143097        12.906046       6712.333333              8.811702
# 145025        12.965207       7121.416667              8.870862
# 147075        12.396912       4034.216667              8.302567
# 148394        13.277750       9734.250000              9.183406
# 155449        12.614892       5016.800000              8.520548
# 155603        12.101950       3003.716667              8.007606
# 158907        13.123627       8343.866667              9.029282
# 158909        13.125155       8356.633333              9.030811
# 166176        13.156156       8619.750000              9.061811
# 172354        12.570296       4797.983333              8.475951
# 173371        12.514898       4539.416667              8.420554
# 180385        12.309112       3695.116667              8.214767
# 191427        12.386154       3991.050000              8.291810
# 207445        12.392270       4015.533333              8.297925
# 210757        12.758877       5793.733333              8.664532
# 213586        12.690506       5410.850000              8.596161
# 213587        12.744681       5712.066667              8.650336
# 213588        12.753853       5764.700000              8.659508
# 213907        12.692097       5419.466667              8.597753
# 218687        12.482086       4392.883333              8.387741
# 218688        12.482101       4392.950000              8.387756
# 218689        12.481907       4392.100000              8.387563
# 218690        12.482173       4393.266667              8.387828
# 218791        12.475546       4364.250000              8.381202
# 218794        12.473631       4355.900000              8.379287
# 223266        12.227908       3406.916667              8.133563
# 223269        12.228157       3407.766667              8.133812
# 238852        12.198937       3309.633333              8.104593

# %%
df_track['track'][117252]
# Out:
# {'FeatureCollection': {'Features': [{'geometry': {'coordinates': [-3.6932255,
#       40.4108902997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 45398,
#      'speed': 0,
#      'var': '28014,ES,Madrid,Madrid,CALLE ALMADEN,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.693267, 40.4111015], 'type': 'Point'},
#     'properties': {'secondsfromstart': 41794,
#      'speed': 0,
#      'var': '28014,ES,Madrid,Madrid,CALLE CENICERO 7,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.6930383, 40.411025799722196],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 38189,
#      'speed': 0,
#      'var': '28014,ES,Madrid,Madrid,PASEO PRADO 36,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.69576679972222, 40.4105871],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 16561,
#      'speed': 1.05,
#      'var': '28012,ES,Madrid,Madrid,CALLE MARQUES DE TOCA 96,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.69527729972222, 40.4101629997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 16501,
#      'speed': 0.75,
#      'var': '28012,ES,Madrid,Madrid,CALLE SANTA INES 4,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.6948911, 40.4100515], 'type': 'Point'},
#     'properties': {'secondsfromstart': 15240,
#      'speed': 1.52,
#      'var': '28012,ES,Madrid,Madrid,CALLE ATOCHA 115,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.69533729972222, 40.4102965],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 15179,
#      'speed': 0.63,
#      'var': '28012,ES,Madrid,Madrid,CALLE SANTA INES 104,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.6953526, 40.4104835997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14999,
#      'speed': 0.61,
#      'var': '28012,ES,Madrid,Madrid,CALLE ATOCHA 107,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.69497659972222, 40.4104074997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14939,
#      'speed': 1,
#      'var': '28012,ES,Madrid,Madrid,CALLE ATOCHA 111,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.695031, 40.4125562997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14819,
#      'speed': 2.3,
#      'var': '28014,ES,Madrid,Madrid,CALLE MORATIN 40,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.6961849997222203, 40.4130182997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14759,
#      'speed': 5.08,
#      'var': '28014,ES,Madrid,Madrid,CALLE HUERTAS 62,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7012431, 40.4167398], 'type': 'Point'},
#     'properties': {'secondsfromstart': 14519,
#      'speed': 3.47,
#      'var': '28014,ES,Madrid,Madrid,CRA SAN JERONIMO 14,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7042539999999997, 40.4167611],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14459,
#      'speed': 4.88,
#      'var': '28013,ES,Madrid,Madrid,PLAZA PUERTA DEL SOL,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7074705999999997, 40.4163229997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14398,
#      'speed': 4.55,
#      'var': '28013,ES,Madrid,Madrid,CALLE MAYOR 30,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7108458, 40.4166791], 'type': 'Point'},
#     'properties': {'secondsfromstart': 14278,
#      'speed': 2.77,
#      'var': '28013,ES,Madrid,Madrid,PLAZA SANTIAGO,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7132475, 40.4173265], 'type': 'Point'},
#     'properties': {'secondsfromstart': 14218,
#      'speed': 4.08,
#      'var': '28013,ES,Madrid,Madrid,CALLE BAILEN,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.71316049972222, 40.4201650997222],
#      'type': 'Point'},
#     'properties': {'secondsfromstart': 14158,
#      'speed': 6.63,
#      'var': '28013,ES,Madrid,Madrid,CALLE BAILEN,Madrid'},
#     'type': 'Feature'},
#    {'geometry': {'coordinates': [-3.7140548, 40.4226601], 'type': 'Point'},
#     'properties': {'secondsfromstart': 14098,
#      'speed': 6.44,
#      'var': '28008,ES,Madrid,Madrid,PLAZA ESPA�A 12,Madrid'},
#     'type': 'Feature'}]}}

# %% [markdown]
# ## 3. Explanatory analysis
#
# After having a preliminary view at the data and getting familiar with it, we'll try to answer the following questions:
#  - Where are the users mostly travelling from?
#  - Where are the users mostly travelling to?

# %% [markdown]
# ## 4. Machine learning & predictions
# Can we train a model to predict bike failures? Can we detect different clusters of users with different behaviors?
